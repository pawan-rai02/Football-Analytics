# %%
import pandas as pd
import matplotlib.pyplot as plt

from mplsoccer import VerticalPitch

# %%
df_raw = pd.read_csv('erling_haaland_2022_understat.csv')

# %%
df = df_raw.copy(deep= True)

df.head()
# Out:
#        id  minute       result      X      Y        xG          player h_a  \
# 0  479846      20  MissedShots  0.936  0.503  0.484085  Erling Haaland   a
# 1  479847      35         Goal  0.885  0.500  0.761169  Erling Haaland   a
# 2  479854      64         Goal  0.864  0.405  0.328053  Erling Haaland   a
# 3  479855      69  MissedShots  0.953  0.552  0.526608  Erling Haaland   a
# 4  479856      75  BlockedShot  0.894  0.710  0.066443  Erling Haaland   a
#
#    player_id situation  season  shotType  match_id    h_team           a_team  \
# 0       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 1       8260   Penalty    2022  LeftFoot     18211  West Ham  Manchester City
# 2       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
# 3       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 4       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
#
# ...

# %%
df['X'] = df['X'] * 100
df['Y'] = df['Y'] * 100

df.head()
# Out:
#        id  minute       result          X          Y        xG  \
# 0  479846      20  MissedShots  93.599998  50.299999  0.484085
# 1  479847      35         Goal  88.500000  50.000000  0.761169
# 2  479854      64         Goal  86.400002  40.500000  0.328053
# 3  479855      69  MissedShots  95.300003  55.200001  0.526608
# 4  479856      75  BlockedShot  89.400002  71.000000  0.066443
#
#            player h_a  player_id situation  season  shotType  match_id  \
# 0  Erling Haaland   a       8260  OpenPlay    2022      Head     18211
# 1  Erling Haaland   a       8260   Penalty    2022  LeftFoot     18211
# 2  Erling Haaland   a       8260  OpenPlay    2022  LeftFoot     18211
# 3  Erling Haaland   a       8260  OpenPlay    2022      Head     18211
# 4  Erling Haaland   a       8260  OpenPlay    2022  LeftFoot     18211
#
#      h_team           a_team  h_goals  a_goals                 date  \
# 0  West Ham  Manchester City        0        2  2022-08-07 15:30:00
# ...

# %%
total_shots = df.shape[0]

total_goals = df[df['result'] == 'Goal'].shape[0]

total_xG = df['xG'].sum()

xG_per_shot = total_xG / total_shots

points_avg_distance = df['X'].mean()

actual_avg_distance = 120 - (df['X'] * 1.2).mean()

# %%
actual_avg_distance
# Out:
# np.float64(11.720000401938833)

# %%
background_color = '#0c0doe'

# %%
import matplotlib.font_manager as font_manager

font_path = ''

font_props = font_manager.FontProperties
