# %%
import pandas as pd
import undetected_chromedriver as uc
from bs4 import BeautifulSoup

# %%
driver = uc.Chrome(version_main=148)

# %%
driver.get('https://fbref.com/en/comps/8/2022-2023/stats/2022-2023-Champions-League-Stats#all_stats_squads_standard')

# %%
df = pd.read_html(driver.page_source, attrs= {'id': "stats_squads_standard_for"})[0]
# Out:
# C:\Users\pawan\AppData\Local\Temp\ipykernel_29364\2994241610.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(driver.page_source, attrs= {'id': "stats_squads_standard_for"})[0]

# %%
df.head()
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                 Squad               # Pl                Age
# 0             nl Ajax                 19               26.4
# 1  es Atlético Madrid                 22               28.6
# 2        es Barcelona                 26               26.4
# 3    de Bayern Munich                 24               26.6
# 4          pt Benfica                 24               26.0
#
#   Unnamed: 3_level_0 Playing Time                   Performance      ...       \
#                 Poss           MP Starts  Min   90s         Gls Ast  ... G-PK
# 0               53.2            6     66  540   6.0          11   9  ...   10
# 1               56.5            6     66  540   6.0           4   3  ...    4
# 2               64.8            6     66  540   6.0          12  10  ...   12
# 3               56.1           10    110  900  10.0          21  19  ...   20
# ...

# %%
player_stats = pd.read_html(driver.page_source, attrs= {'id' : "stats_standard"})[0]
player_stats.head()
# Out:
# C:\Users\pawan\AppData\Local\Temp\ipykernel_29364\4148068724.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   player_stats = pd.read_html(driver.page_source, attrs= {'id' : "stats_standard"})[0]
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Rk             Player             Nation                Pos
# 0                  1         Liel Abada             il ISR              MF,FW
# 1                  2  Oliver Abildgaard             dk DEN              DF,MF
# 2                  3  Mohammad Abu Fani             il ISR                 MF
# 3                  4   Francesco Acerbi             it ITA                 DF
# 4                  5       Marcos Acuña             ar ARG              DF,MF
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Playing Time  \
# ...

# %%
player_stats
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk             Player             Nation
# 0                    1         Liel Abada             il ISR
# 1                    2  Oliver Abildgaard             dk DEN
# 2                    3  Mohammad Abu Fani             il ISR
# 3                    4   Francesco Acerbi             it ITA
# 4                    5       Marcos Acuña             ar ARG
# ..                 ...                ...                ...
# 751                724    Piotr Zieliński             pl POL
# 752                725       Hakim Ziyech             ma MAR
# 753                 Rk             Player             Nation
# 754                726   Oleksandr Zubkov             ua UKR
# 755                727      Neven Đurasek             hr CRO
#
#     Unnamed: 3_level_0   Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                    Pos                Squad                Age
# ...
