# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_raw = pd.read_csv('historical_prem_standings.csv')

# %%
df = df_raw.copy(deep = 1)

# %%
df.head()
# Out:
#    Rk           Squad  MP  ...     Top Team Scorer        Goalkeeper  Year
# 0   1  Manchester Utd  38  ...   Eric Cantona - 14  Peter Schmeichel  1996
# 1   2   Newcastle Utd  38  ...  Les Ferdinand - 25      Shaka Hislop  1996
# 2   3       Liverpool  38  ...  Robbie Fowler - 28       David James  1996
# 3   4     Aston Villa  38  ...   Dwight Yorke - 17      Mark Bosnich  1996
# 4   5         Arsenal  38  ...     Ian Wright - 15      David Seaman  1996
#
# [5 rows x 13 columns]

# %%
x = df['GF'].values.reshape(-1, 1)
y = df['Rk'].values.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .2, random_state = 42)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MSE:", mse)
print("R2:", r2)
# Out:
# MSE: 11.515877171127066
# R2: 0.6326193482679692

# %%
plt.scatter(x, y, color = 'orange')
plt.plot(x_test, y_pred, color = 'brown')
plt.ylim(0, 21)
# Out:
# (0.0, 21.0)
