# %%
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('classification_data.csv')

# %%
df.count()
# Out:
# Rk          2865
# Player      2865
# Nation      2862
# Pos         2865
# Squad       2865
# Comp        2865
# Age         2862
# Born        2862
# MP          2865
# Starts      2865
# Min         2865
# 90s         2865
# Gls         2865
# Ast         2865
# G+A         2865
# G-PK        2865
# PK          2865
# PKatt       2865
# CrdY        2865
# CrdR        2865
# xG          2851
# npxG        2851
# xAG         2851
# npxG+xAG    2851
# PrgC        2851
# PrgP        2851
# PrgR        2851
# dtype: int64

# %%
df.head()
# Out:
#   Rk             Player   Nation    Pos  ... npxG+xAG PrgC PrgP PrgR
# 0  1         Max Aarons  eng ENG     DF  ...      0.8   19   40   22
# 1  2   Brenden Aaronson   us USA  MF,FW  ...      2.9   26   31   56
# 2  3    Paxten Aaronson   us USA     MF  ...      0.2    2    5    7
# 3  4   Yunis Abdelhamid   ma MAR     DF  ...      2.7   33  117    7
# 4  5  Salis Abdul Samed   gh GHA     MF  ...      1.3    8   77   20
#
# [5 rows x 27 columns]

# %%
df['Pos'] = df['Pos'].apply(lambda x : x.split(',')[0])

# %%
df['Pos'].unique()
# Out:
# array(['DF', 'MF', 'FW', 'Pos', 'GK'], dtype=object)

# %%
df = df[df['Pos'] != 'Pos']

# %%
df['Pos'].unique()
# Out:
# array(['DF', 'MF', 'FW', 'GK'], dtype=object)

# %%
df.count()
# Out:
# Rk          2755
# Player      2755
# Nation      2752
# Pos         2755
# Squad       2755
# Comp        2755
# Age         2752
# Born        2752
# MP          2755
# Starts      2755
# Min         2755
# 90s         2755
# Gls         2755
# Ast         2755
# G+A         2755
# G-PK        2755
# PK          2755
# PKatt       2755
# CrdY        2755
# CrdR        2755
# xG          2741
# npxG        2741
# xAG         2741
# npxG+xAG    2741
# PrgC        2741
# PrgP        2741
# PrgR        2741
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Rk           0
# Player       0
# Nation       3
# Pos          0
# Squad        0
# Comp         0
# Age          3
# Born         3
# MP           0
# Starts       0
# Min          0
# 90s          0
# Gls          0
# Ast          0
# G+A          0
# G-PK         0
# PK           0
# PKatt        0
# CrdY         0
# CrdR         0
# xG          14
# npxG        14
# xAG         14
# npxG+xAG    14
# PrgC        14
# PrgP        14
# PrgR        14
# dtype: int64

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (2737, 27)

# %%
df['Pos'].value_counts()
# Out:
# Pos
# DF    977
# MF    870
# FW    711
# GK    179
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

df['Pos'] = le.fit_transform(df['Pos'])

print(df['Pos'].unique())
# Out:
# [0 3 1 2]

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP',
#        'Starts', 'Min', '90s', 'Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt',
#        'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP',
#        'PrgR'],
#       dtype='object')

# %%
x = df[['Gls', 'Ast', 'G+A', 'G-PK', 'PK', 'PKatt',
       'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP',
       'PrgR']]

y = df["Pos"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = .2, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()

clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = clf.predict(x_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.6167883211678832

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[121,  10,  11,  59],
#        [ 14,  85,   5,  30],
#        [  0,   0,  29,   2],
#        [ 42,  28,   9, 103]])
