# %%
from mplsoccer import Pitch

# %%
pitch = Pitch()

# %%
fig, ax = pitch.draw()

# %%
pitch = Pitch(
    pitch_color= 'grass',
    line_color= 'white',
    stripe= True,
    linewidth= 3
)

fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type = 'statsbomb')

fig, ax = pitch.draw()
