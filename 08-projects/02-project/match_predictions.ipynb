# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df_raw = pd.read_csv('project2.csv')

# %%
df = df_raw.copy(deep= True)

# %%
df.head()
# Out:
#     Wk  Day        Date   Time        Home   xG Score  xG.1           Away  \
# 0  1.0  Fri  2018-08-17  20:15      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0  Fri  2018-08-17  22:15       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Sat  2018-08-18  18:15  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Sat  2018-08-18  20:15  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Sat  2018-08-18  22:15   Barcelona  3.2   3–0   0.3         Alavés
#
#    Attendance                          Venue           Referee
# 0     10368.0  Estadi Municipal de Montilivi  Guillermo Cuadra
# 1     46225.0      Estadio Benito Villamarín  Ignacio Iglesias
# 2     16215.0            Estadio de Balaídos    Santiago Jaime
# 3     16250.0         Estadio de la Cerámica      Mario Melero
# 4     52356.0                       Camp Nou      José Sánchez

# %%
df.count()
# Out:
# Wk            4560
# Day           4560
# Date          4560
# Time          4520
# Home          4560
# xG            4433
# Score         4433
# xG.1          4433
# Away          4560
# Attendance    3502
# Venue         4560
# Referee       4433
# dtype: int64

# %%
df.shape
# Out:
# (4560, 12)

# %%
df[df.isnull().any(axis= 1)]
# Out:
#         Wk  Day        Date   Time            Home   xG Score  xG.1  \
# 1029  24.0  Tue  2020-03-10  20:00           Eibar  2.0   1–2   1.2
# 1030  28.0  Thu  2020-06-11  22:00         Sevilla  1.7   2–0   0.5
# 1031  28.0  Fri  2020-06-12  19:30         Granada  2.3   2–1   0.6
# 1032  28.0  Fri  2020-06-12  22:00        Valencia  1.0   1–1   1.4
# 1033  28.0  Sat  2020-06-13  14:00        Espanyol  2.5   2–0   0.1
# ...    ...  ...         ...    ...             ...  ...   ...   ...
# 4555  38.0  Sun  2024-05-19  16:00       Brentford  NaN   NaN   NaN
# 4556  38.0  Sun  2024-05-19  16:00         Chelsea  NaN   NaN   NaN
# 4557  38.0  Sun  2024-05-19  16:00  Crystal Palace  NaN   NaN   NaN
# 4558  38.0  Sun  2024-05-19  16:00       Liverpool  NaN   NaN   NaN
# 4559  38.0  Sun  2024-05-19  16:00         Burnley  NaN   NaN   NaN
#
#                  Away  Attendance                          Venue  \
# 1029    Real Sociedad         NaN    Estadio Municipal de Ipurúa
# 1030            Betis         NaN  Estadio Ramón Sánchez Pizjuán
# 1031           Getafe         NaN     Estadio Nuevo Los Cármenes
# 1032          Levante         NaN            Estadio de Mestalla
# 1033           Alavés         NaN                   RCDE Stadium
# ...               ...         ...                            ...
# 4555    Newcastle Utd         NaN        Gtech Community Stadium
# 4556      Bournemouth         NaN                Stamford Bridge
# 4557      Aston Villa         NaN                  Selhurst Park
# 4558           Wolves         NaN                        Anfield
# 4559  Nott'ham Forest         NaN                      Turf Moor
#
#                   Referee
# 1029          David Medié
# 1030  Antonio Matéu Lahoz
# 1031          David Medié
# 1032       Alberola Rojas
# 1033       Pablo González
# ...                   ...
# 4555                  NaN
# 4556                  NaN
# 4557                  NaN
# 4558                  NaN
# 4559                  NaN
#
# [1058 rows x 12 columns]

# %%
df = df.dropna(subset= ['Score'])

df.shape
# Out:
# (4433, 12)

# %%
df = df.drop(columns= ['Attendance', 'Time'])

# %%
df.head()
# Out:
#     Wk  Day        Date        Home   xG Score  xG.1           Away  \
# 0  1.0  Fri  2018-08-17      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0  Fri  2018-08-17       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Sat  2018-08-18  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Sat  2018-08-18  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Sat  2018-08-18   Barcelona  3.2   3–0   0.3         Alavés
#
#                            Venue           Referee
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra
# 1      Estadio Benito Villamarín  Ignacio Iglesias
# 2            Estadio de Balaídos    Santiago Jaime
# 3         Estadio de la Cerámica      Mario Melero
# 4                       Camp Nou      José Sánchez

# %%
df[['home_goals', 'away_goals']] = df['Score'].str.split('–', expand= True).astype(int)

# %%
df.head(
    
)
# Out:
#     Wk  Day        Date        Home   xG Score  xG.1           Away  \
# 0  1.0  Fri  2018-08-17      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0  Fri  2018-08-17       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Sat  2018-08-18  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Sat  2018-08-18  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Sat  2018-08-18   Barcelona  3.2   3–0   0.3         Alavés
#
#                            Venue           Referee  home_goals  away_goals
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra           0           0
# 1      Estadio Benito Villamarín  Ignacio Iglesias           0           3
# 2            Estadio de Balaídos    Santiago Jaime           1           1
# 3         Estadio de la Cerámica      Mario Melero           1           2
# 4                       Camp Nou      José Sánchez           3           0

# %%
def det_res(row):
    if row['home_goals'] > row['away_goals']:
        return 'Home win'
    
    elif row['home_goals'] < row['away_goals']:
        return 'Away win'

    else:
        return 'Draw'

# %%
df['result'] = df.apply(det_res, axis= 1)

# %%
df['result']
# Out:
# 0           Draw
# 1       Away win
# 2           Draw
# 3       Away win
# 4       Home win
#           ...
# 4498        Draw
# 4499    Away win
# 4500    Away win
# 4501    Away win
# 4502    Home win
# Name: result, Length: 4433, dtype: str

# %%
df['Date'] = pd.to_datetime(df['Date'])

df['Day'] = df['Date'].dt.day_name()

# %%
df.head()
# Out:
#     Wk       Day       Date        Home   xG Score  xG.1           Away  \
# 0  1.0    Friday 2018-08-17      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0    Friday 2018-08-17       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Saturday 2018-08-18  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Saturday 2018-08-18  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Saturday 2018-08-18   Barcelona  3.2   3–0   0.3         Alavés
#
#                            Venue           Referee  home_goals  away_goals  \
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra           0           0
# 1      Estadio Benito Villamarín  Ignacio Iglesias           0           3
# 2            Estadio de Balaídos    Santiago Jaime           1           1
# 3         Estadio de la Cerámica      Mario Melero           1           2
# 4                       Camp Nou      José Sánchez           3           0
#
#      result
# 0      Draw
# 1  Away win
# 2      Draw
# 3  Away win
# 4  Home win

# %%
df['season_start'] = df['Date'].apply(lambda x : x.year == 1 if x.month < 8 else x.year)

# %%
df.head()
# Out:
#     Wk       Day       Date        Home   xG Score  xG.1           Away  \
# 0  1.0    Friday 2018-08-17      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0    Friday 2018-08-17       Betis  0.9   0–3   2.5        Levante
# 2  1.0  Saturday 2018-08-18  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0  Saturday 2018-08-18  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0  Saturday 2018-08-18   Barcelona  3.2   3–0   0.3         Alavés
#
#                            Venue           Referee  home_goals  away_goals  \
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra           0           0
# 1      Estadio Benito Villamarín  Ignacio Iglesias           0           3
# 2            Estadio de Balaídos    Santiago Jaime           1           1
# 3         Estadio de la Cerámica      Mario Melero           1           2
# 4                       Camp Nou      José Sánchez           3           0
#
#      result season_start
# 0      Draw         2018
# 1  Away win         2018
# 2      Draw         2018
# 3  Away win         2018
# 4  Home win         2018

# %%
df = pd.get_dummies(df, columns= ['Day'])

# %%
df.head()
# Out:
#     Wk       Date        Home   xG Score  xG.1           Away  \
# 0  1.0 2018-08-17      Girona  0.7   0–0   0.0     Valladolid
# 1  1.0 2018-08-17       Betis  0.9   0–3   2.5        Levante
# 2  1.0 2018-08-18  Celta Vigo  0.6   1–1   0.6       Espanyol
# 3  1.0 2018-08-18  Villarreal  1.6   1–2   0.7  Real Sociedad
# 4  1.0 2018-08-18   Barcelona  3.2   3–0   0.3         Alavés
#
#                            Venue           Referee  home_goals  away_goals  \
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra           0           0
# 1      Estadio Benito Villamarín  Ignacio Iglesias           0           3
# 2            Estadio de Balaídos    Santiago Jaime           1           1
# 3         Estadio de la Cerámica      Mario Melero           1           2
# 4                       Camp Nou      José Sánchez           3           0
#
#      result season_start  Day_Friday  Day_Monday  Day_Saturday  Day_Sunday  \
# 0      Draw         2018        True       False         False       False
# 1  Away win         2018        True       False         False       False
# 2      Draw         2018       False       False          True       False
# 3  Away win         2018       False       False          True       False
# 4  Home win         2018       False       False          True       False
#
#    Day_Thursday  Day_Tuesday  Day_Wednesday
# 0         False        False          False
# 1         False        False          False
# 2         False        False          False
# 3         False        False          False
# 4         False        False          False

# %%
df.reset_index(drop = True, inplace= True)

# %%
for x in df.Home.unique():
    
    temp_df = df[(df['Home'] == x) | (df['Away'] == x)]

    temp_df = temp_df.sort_values(['Date'])

    temp_df['goal_value_to_calc'] = temp_df.apply(lambda y : y['home_goals'] if y['Home'] == x else y['away_goals'], axis= 1)
    
    temp_df['rolling_avg_goals'] = temp_df['goal_value_to_calc'].rolling(window= 5, closed= 'left', min_periods= 1).mean()

    for index, row in temp_df.iterrows():
        if row['Home'] == x:
            df['home_rolling_avg_goals'] = pd.NA
            df['away_rolling_avg_goals'] = pd.NA

            for x in df.Home.unique():
                temp_df = df[(df['Home'] == x) | (df['Away'] == x)]
                temp_df = temp_df.sort_values(['Date'])

                temp_df['goal_value_to_calc'] = temp_df.apply(
                    lambda y: y['home_goals'] if y['Home'] == x else y['away_goals'],
                    axis=1
                )
                temp_df['rolling_avg_goals'] = temp_df['goal_value_to_calc'].rolling(
                    window=5, closed='left', min_periods=1
                ).mean()

                for index, row in temp_df.iterrows():
                    if row['Home'] == x:
                        df.at[index, 'home_rolling_avg_goals'] = row['rolling_avg_goals']
                    else:
                        df.at[index, 'away_rolling_avg_goals'] = row['rolling_avg_goals']

        else:
            df.at[index, 'away_rolling_avg_goals'] == row['rolling_avg_goals']

# %%
temp_df.head()
# Out:
#        Wk       Date        Home   xG Score  xG.1        Away  \
# 4114  1.0 2023-08-12    Brighton  4.0   4–1   1.5  Luton Town
# 4129  3.0 2023-08-25     Chelsea  2.2   3–0   0.4  Luton Town
# 4139  4.0 2023-09-01  Luton Town  1.4   1–2   1.0    West Ham
# 4150  5.0 2023-09-16      Fulham  1.0   1–0   1.1  Luton Town
# 4160  6.0 2023-09-23  Luton Town  2.1   1–1   0.6      Wolves
#
#                                        Venue            Referee  home_goals  \
# 4114  The American Express Community Stadium        David Coote           4
# 4129                         Stamford Bridge       Robert Jones           3
# 4139                 Kenilworth Road Stadium       Paul Tierney           1
# 4150                          Craven Cottage  Michael Salisbury           1
# 4160                 Kenilworth Road Stadium       Joshua Smith           1
#
#       ...  Day_Monday Day_Saturday Day_Sunday  Day_Thursday  Day_Tuesday  \
# 4114  ...       False         True      False         False        False
# 4129  ...       False        False      False         False        False
# 4139  ...       False        False      False         False        False
# 4150  ...       False         True      False         False        False
# 4160  ...       False         True      False         False        False
#
#       Day_Wednesday  home_rolling_avg_goals  away_rolling_avg_goals  \
# 4114          False                     1.8                    <NA>
# 4129          False                     0.8                    <NA>
# 4139          False                    <NA>                     2.2
# 4150          False                     1.0                    <NA>
# 4160          False                    <NA>                     1.0
#
#       goal_value_to_calc  rolling_avg_goals
# 4114                   1                NaN
# 4129                   0           1.000000
# 4139                   1           0.500000
# 4150                   0           0.666667
# 4160                   1           0.500000
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Wk', 'Date', 'Home', 'xG', 'Score', 'xG.1', 'Away', 'Venue', 'Referee',
#        'home_goals', 'away_goals', 'result', 'season_start', 'Day_Friday',
#        'Day_Monday', 'Day_Saturday', 'Day_Sunday', 'Day_Thursday',
#        'Day_Tuesday', 'Day_Wednesday', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals'],
#       dtype='str')

# %%
for x in df.Home.unique():
    
    temp_df = df[(df['Home'] == x) | (df['Away'] == x)]

    temp_df = temp_df.sort_values(['Date'])

    temp_df['xG_value_to_calc'] = temp_df.apply(lambda y : y['xG'] if y['Home'] == x else y['xG.1'], axis= 1)
    
    temp_df['rolling_avg_xG'] = temp_df['xG_value_to_calc'].rolling(window= 5, closed= 'left', min_periods= 1).mean()

    for index, row in temp_df.iterrows():
        if row['Home'] == x:
            df['home_rolling_avg_xG'] = pd.NA
            df['away_rolling_avg_xG'] = pd.NA

            for x in df.Home.unique():
                temp_df = df[(df['Home'] == x) | (df['Away'] == x)]
                temp_df = temp_df.sort_values(['Date'])

                temp_df['xG_value_to_calc'] = temp_df.apply(
                    lambda y: y['xG'] if y['Home'] == x else y['xG.1'],
                    axis=1
                )
                temp_df['rolling_avg_xG'] = temp_df['xG_value_to_calc'].rolling(
                    window=5, closed='left', min_periods=1
                ).mean()

                for index, row in temp_df.iterrows():
                    if row['Home'] == x:
                        df.at[index, 'home_rolling_avg_xG'] = row['rolling_avg_xG']
                    else:
                        df.at[index, 'away_rolling_avg_xG'] = row['rolling_avg_xG']

        else:
            df.at[index, 'away_rolling_avg_xG'] == row['rolling_avg_xG']

# %%
df.columns
# Out:
# Index(['Wk', 'Date', 'Home', 'xG', 'Score', 'xG.1', 'Away', 'Venue', 'Referee',
#        'home_goals', 'away_goals', 'result', 'season_start', 'Day_Friday',
#        'Day_Monday', 'Day_Saturday', 'Day_Sunday', 'Day_Thursday',
#        'Day_Tuesday', 'Day_Wednesday', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG'],
#       dtype='str')

# %%
df = df.dropna(subset= ['home_rolling_avg_goals',
       'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG'])

# %%
df[(df['Home'] == 'Manchester City') | (df['Away'] == 'Manchester City')]
# Out:
#         Wk       Date             Home   xG Score  xG.1             Away  \
# 397    2.0 2018-08-19  Manchester City  4.2   6–1   0.7     Huddersfield
# 400    3.0 2018-08-25           Wolves  1.0   1–1   1.6  Manchester City
# 416    4.0 2018-09-01  Manchester City  2.0   2–1   0.5    Newcastle Utd
# 421    5.0 2018-09-15  Manchester City  4.8   3–0   0.4           Fulham
# 432    6.0 2018-09-22     Cardiff City  0.1   0–5   2.5  Manchester City
# ...    ...        ...              ...  ...   ...   ...              ...
# 4386  28.0 2024-03-10        Liverpool  2.7   1–1   1.6  Manchester City
# 4402  30.0 2024-03-31  Manchester City  1.0   0–0   0.7          Arsenal
# 4410  31.0 2024-04-03  Manchester City  3.4   4–1   0.8      Aston Villa
# 4413  32.0 2024-04-06   Crystal Palace  1.1   2–4   1.9  Manchester City
# 4424  33.0 2024-04-13  Manchester City  4.2   5–1   0.5       Luton Town
#
#                      Venue          Referee  home_goals  ...  Day_Monday  \
# 397         Etihad Stadium   Andre Marriner           6  ...       False
# 400       Molineux Stadium  Martin Atkinson           1  ...       False
# 416         Etihad Stadium     Kevin Friend           2  ...       False
# 421         Etihad Stadium   Stuart Attwell           3  ...       False
# 432   Cardiff City Stadium   Michael Oliver           0  ...       False
# ...                    ...              ...         ...  ...         ...
# 4386               Anfield   Michael Oliver           1  ...       False
# 4402        Etihad Stadium   Anthony Taylor           0  ...       False
# 4410        Etihad Stadium   Darren England           4  ...       False
# 4413         Selhurst Park     Paul Tierney           2  ...       False
# 4424        Etihad Stadium      John Brooks           5  ...       False
#
#      Day_Saturday Day_Sunday  Day_Thursday  Day_Tuesday  Day_Wednesday  \
# 397         False       True         False        False          False
# 400          True      False         False        False          False
# 416          True      False         False        False          False
# 421          True      False         False        False          False
# 432          True      False         False        False          False
# ...           ...        ...           ...          ...            ...
# 4386        False       True         False        False          False
# 4402        False       True         False        False          False
# 4410        False      False         False        False           True
# 4413         True      False         False        False          False
# 4424         True      False         False        False          False
#
#       home_rolling_avg_goals  away_rolling_avg_goals  home_rolling_avg_xG  \
# 397                      2.0                     0.0                  1.7
# 400                      1.0                     4.0                 1.05
# 416                      3.0                0.666667                  2.5
# 421                     2.75                    1.75                2.375
# 432                      0.6                     2.8                 0.98
# ...                      ...                     ...                  ...
# 4386                     2.6                     1.6                 2.26
# 4402                     1.4                     4.6                 2.28
# 4410                     1.2                     2.0                 1.96
# 4413                     1.2                     1.8                 1.36
# 4424                     2.4                     1.4                 2.24
#
#       away_rolling_avg_xG
# 397                   0.3
# 400                  2.95
# 416              0.933333
# 421                   1.3
# 432                  2.86
# ...                   ...
# 4386                 2.28
# 4402                 2.46
# 4410                  1.6
# 4413                 2.18
# 4424                 0.98
#
# [221 rows x 24 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
df.columns
# Out:
# Index(['Wk', 'Date', 'Home', 'xG', 'Score', 'xG.1', 'Away', 'Venue', 'Referee',
#        'home_goals', 'away_goals', 'result', 'season_start', 'Day_Friday',
#        'Day_Monday', 'Day_Saturday', 'Day_Sunday', 'Day_Thursday',
#        'Day_Tuesday', 'Day_Wednesday', 'home_rolling_avg_goals',
#        'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG'],
#       dtype='str')

# %%
features = [cols for cols in df.drop(columns= ['Date', 'xG', 'xG.1', 'Home', 'Away', 'Referee', 'Venue', 'Score', 'result', 'home_goals', 'away_goals', 'season_start'])]

# %%
features
# Out:
# ['Wk',
#  'Day_Friday',
#  'Day_Monday',
#  'Day_Saturday',
#  'Day_Sunday',
#  'Day_Thursday',
#  'Day_Tuesday',
#  'Day_Wednesday',
#  'home_rolling_avg_goals',
#  'away_rolling_avg_goals',
#  'home_rolling_avg_xG',
#  'away_rolling_avg_xG']

# %%
train_df = df[df['season_start'] <= 2022]
test_df  = df[df['season_start'] == 2023]

x_train = train_df[features]
y_train = train_df['result']

x_test = test_df[features]
y_test = test_df['result']

# %%
train_df.shape
# Out:
# (4024, 24)

# %%
x_train.shape
# Out:
# (4024, 12)

# %%
x_test.shape
# Out:
# (374, 12)

# %%
clf = RandomForestClassifier(random_state= 42)

clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred = clf.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.4358288770053476

# %%
df['result'].value_counts(normalize= True)
# Out:
# result
# Home win    0.445884
# Away win    0.303547
# Draw        0.250568
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'n_estimators' : [50, 100, 200],
    'max_depth' : [5, 10, 15, 20],
}

gs = GridSearchCV(estimator=clf, param_grid=param_grid, cv = 5)

# %%
gs.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42),
#              param_grid={'max_depth': [5, 10, 15, 20],
#                          'n_estimators': [50, 100, 200]})

# %%
gs.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 50}

# %%
clf_new = RandomForestClassifier(random_state= 42, max_depth= 5, n_estimators= 50)

clf_new.fit(x_train, y_train)

pred2 = clf_new.predict(x_test)

accuracy_score(y_test, pred2)
# Out:
# 0.48663101604278075

# %%
df = pd.get_dummies(df, columns= ['Home', 'Away', 'Referee', 'Venue'])

df.head()
# Out:
#      Wk       Date   xG Score  xG.1  home_goals  away_goals    result  \
# 10  2.0 2018-08-24  1.4   2–0   0.6           2           0  Home win
# 11  2.0 2018-08-24  1.7   2–2   1.6           2           2      Draw
# 12  2.0 2018-08-25  0.6   0–0   0.9           0           0      Draw
# 13  2.0 2018-08-25  0.9   1–0   1.5           1           0  Home win
# 14  2.0 2018-08-25  0.4   0–1   1.0           0           1  Away win
#
#    season_start  Day_Friday  ...  \
# 10         2018        True  ...
# 11         2018        True  ...
# 12         2018       False  ...
# 13         2018       False  ...
# 14         2018       False  ...
#
#     Venue_The American Express Community Stadium  Venue_The City Ground  \
# 10                                         False                  False
# 11                                         False                  False
# 12                                         False                  False
# 13                                         False                  False
# 14                                         False                  False
#
#     Venue_The Hawthorns  Venue_The John Smith's Stadium  \
# 10                False                           False
# 11                False                           False
# 12                False                           False
# 13                False                           False
# 14                False                           False
#
#     Venue_Tottenham Hotspur Stadium  Venue_Turf Moor  \
# 10                            False            False
# 11                            False            False
# 12                            False            False
# 13                            False            False
# 14                            False            False
#
#    Venue_Vicarage Road Stadium Venue_Villa Park Venue_Vitality Stadium  \
# 10                       False            False                  False
# 11                       False            False                  False
# 12                       False            False                  False
# 13                       False            False                  False
# 14                       False            False                  False
#
#    Venue_Wembley Stadium
# 10                 False
# 11                 False
# 12                 False
# 13                 False
# 14                 False
#
# [5 rows x 263 columns]

# %%
features = [cols for cols in df.drop(columns= ['Date', 'xG', 'xG.1', 'Score', 'result', 'home_goals', 'away_goals', 'season_start'])]

# %%
train_df = df[df['season_start'] <= 2022]
test_df  = df[df['season_start'] == 2023]

x_train = train_df[features]
y_train = train_df['result']

x_test = test_df[features]
y_test = test_df['result']

# %%
param_grid = {
    'n_estimators' : [50, 100, 200],
    'max_depth' : [5, 10, 15, 20],
}

gs = GridSearchCV(estimator=clf, param_grid=param_grid, cv = 5)

gs.fit(x_train, y_train)

gs.best_params_
# Out:
# {'max_depth': 20, 'n_estimators': 200}

# %%
clf = RandomForestClassifier(random_state= 42, max_depth= 20, n_estimators= 200)

clf.fit(x_train, y_train)

y_pred = clf.predict(x_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.5187165775401069

# %%
home_team = 'Chealse'
away_team = 'Manchester City'
referee = 'Anthony Taylor'

# %%
# Essentially, we need to create a row of data that represents the match we want to predict
# We'll use the features we used to train the model

# Create a row of data for the hypothetical match
data = {
    'Wk': [25],
    'home_rolling_avg_goals': [1.9],
    'away_rolling_avg_goals': [1.2],
    'home_rolling_avg_xG': [2.1],
    'away_rolling_avg_xG': [1.3],
    'Day_Saturday': [1],
    'Home_Chelsea': [1],
    'Away_Manchester Utd': [1],
    'Referee_Anthony Taylor': [1],
    'Venue_Stamford Bridge': [1]
}

match = pd.DataFrame(columns=x_train.columns, data=data)

match.fillna(0, inplace=True)
# Out:
#    Wk Day_Friday Day_Monday  Day_Saturday Day_Sunday Day_Thursday Day_Tuesday  \
# 0  25          0          0             1          0            0           0
#
#   Day_Wednesday  home_rolling_avg_goals  away_rolling_avg_goals  ...  \
# 0             0                     1.9                     1.2  ...
#
#    Venue_The American Express Community Stadium  Venue_The City Ground  \
# 0                                             0                      0
#
#   Venue_The Hawthorns Venue_The John Smith's Stadium  \
# 0                   0                              0
#
#   Venue_Tottenham Hotspur Stadium Venue_Turf Moor Venue_Vicarage Road Stadium  \
# 0                               0               0                           0
#
#   Venue_Villa Park Venue_Vitality Stadium Venue_Wembley Stadium
# 0                0                      0                     0
#
# [1 rows x 255 columns]

# %%
# Use the Random Forest model to predict the outcome of the match
prediction = clf.predict(match)
prediction
# Out:
# array(['Home win'], dtype=object)
